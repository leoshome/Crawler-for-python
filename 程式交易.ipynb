# %%
# %pylab inline
import pandas as pd
import numpy as np
import pandas.io.data as web
import datetime
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
start = datetime.datetime(2011, 3, 2)
end = datetime.datetime(2015, 4, 1)

# %%
symbol = ['AAPL', 'FOX', 'EBAY' ]
stockPrice = web.get_data_yahoo(symbol, start, end)['Close']
#stockPrice['MA10'] = pd.rolling_mean(stockPrice['Close'], 10).shift(1)
#stockPrice['MA120'] = pd.rolling_mean(stockPrice['Close'], 120).shift(1)
stockPrice.head(n = 30)
# Out:
#                  AAPL   EBAY       FOX
# Date
# 2011-03-02  352.12003  32.68  18.15000
# 2011-03-03  359.55997  32.93  18.49000
# 2011-03-04  360.00000  32.01  18.72000
# 2011-03-07  355.35995  31.50  18.12000
# 2011-03-08  355.76001  31.67  18.31000
# 2011-03-09  352.47003  31.33  18.11000
# 2011-03-10  346.67001  31.08  17.74000
# 2011-03-11  351.99002  30.92  17.95000
# 2011-03-14  353.56000  30.77  17.75000
# 2011-03-15  345.42999  30.44  17.25000
# 2011-03-16  330.01004  29.73  16.93000
# 2011-03-17  334.63995  29.95  17.11999
# 2011-03-18  330.66998  30.47  17.15000
# 2011-03-21  339.30002  30.58  17.69000
# 2011-03-22  341.20001  30.22  17.67999
# 2011-03-23  339.18997  30.67  17.84000
# 2011-03-24  344.97000  31.76  18.02000
# 2011-03-25  351.54001  31.70  18.08000
# 2011-03-28  350.44000  30.34  18.10000
# 2011-03-29  350.95996  31.08  18.29000
# 2011-03-30  348.63004  31.63  18.56000
# 2011-03-31  348.50998  31.04  18.62000
# 2011-04-01  344.56000  31.36  18.91000
# ...

# %%
stockPrice.describe()
plot(stockPrice['FOX'])
